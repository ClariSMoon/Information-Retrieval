# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
topics = pd.read_csv('/kaggle/input/nir-2024/sampled_train_topics.csv')
qrels = pd.read_csv('/kaggle/input/nir-2024/sampled_train_qrels.csv')

# %%
dataset = pt.get_dataset('irds:dpr-w100')

# %%
indexer = pt.IterDictIndexer('./indices/dpr-w100')

# %%
index_ref = indexer.index(dataset.get_corpus_iter(), fields=['text', 'title'])
# Out:
# dpr-w100 documents:   0%|          | 0/21015324 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 index_ref = indexer.index(dataset.get_corpus_iter(), fields=['text', 'title'])
#
# File /opt/conda/lib/python3.10/site-packages/pyterrier/index.py:1011, in _IterDictIndexer_fifo.index(self, it, fields, meta, meta_lengths)
#    1008     if meta_lengths is not None:
#    1009         self.meta = {zip(meta, meta_lengths)}
# -> 1011 self._setup(fields, self.meta, None)
#    1013 os.makedirs(self.index_dir, exist_ok=True) # ParallelIndexer expects the directory to exist
#    1015 Indexer, Merger = self.indexerAndMergerClasses()
#
# File /opt/conda/lib/python3.10/site-packages/pyterrier/index.py:850, in _BaseIterDictIndexer._setup(self, fields, meta, meta_lengths)
#     840 def _setup(self, fields, meta, meta_lengths):
#     841     """
#     842     Index the specified iter of dicts with the (optional) specified fields
#     843
#    (...)
#     848         meta_lengths(list[int]): deprecated
#     849     """
# --> 850     self.checkIndexExists()
#     851     if isinstance(meta, dict):
#     852         self.meta = meta
#
# File /opt/conda/lib/python3.10/site-packages/pyterrier/index.py:520, in TerrierIndexer.checkIndexExists(self)
#     518 if os.path.isfile(self.path):
#     519     if not self.overwrite:
# --> 520         raise ValueError("Index already exists at " + self.path)
#     521 if self.index_called:
#     522     raise Exception("Index method can be called only once")
#
# ValueError: Index already exists at ./indices/dpr-w100/data.properties

# %%
index_ref = pt.IndexRef.of("./indices/dpr-w100/data.properties")
index = pt.IndexFactory.of(index_ref)
print(index.getCollectionStatistics().toString())
# Out:
# 12:28:18.168 [main] WARN org.terrier.structures.FSADocumentIndex - This index has fields, but FSADocumentIndex is used (which stores fields lengths on disk); If using field-based models such as BM25F, change to index.document.class in the index  properties file to FSAFieldDocumentIndex or FSADocumentIndexInMemFields to support efficient retrieval. If you don't use (e.g.) BM25F, this warning can be ignored
# 12:28:22.947 [main] WARN org.terrier.structures.BaseCompressingMetaIndex - Structure meta reading lookup file directly from disk (SLOW) - try index.meta.index-source=fileinmem in the index properties file. 160.3 MiB of memory would be required.
# 12:28:23.003 [main] WARN org.terrier.structures.BaseCompressingMetaIndex - Structure meta reading data file directly from disk (SLOW) - try index.meta.data-source=fileinmem in the index properties file. 470.4 MiB of memory would be required.
# Number of documents: 21015324
# Number of terms: 4023297
# Number of postings: 1000890089
# Number of fields: 2
# Number of tokens: 1286954378
# Field names: [text, title]
# Positions:   false

# %%
import random
import time

search_times = []

# randomly selected 1000 items
ix_range = random.sample(range(0, 4023296), 1000)

# timimg
for ix, kv in enumerate(index.getLexicon()):
    start_time = time.time()
    if ix in ix_range:
        pointer = index.getLexicon()[kv.getKey()]
    end_time = time.time()
    search_time = end_time - start_time
    search_times.append(search_time)

# %%
print(sum(search_times)/1000)
# Out:
# 0.04223601794242859

# %%
import matplotlib.pyplot as plt
import pyterrier as pt
if not pt.started():
    pt.init()

# %%
pip install python-terrier
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.10.1.tar.gz (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from python-terrier) (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from python-terrier) (2.2.2)
# Collecting wget (from python-terrier)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from python-terrier) (4.66.1)
# Collecting pyjnius>=1.4.2 (from python-terrier)
#   Downloading pyjnius-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting matchpy (from python-terrier)
#   Downloading matchpy-0.5.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: deprecated in /opt/conda/lib/python3.10/site-packages (from python-terrier) (1.2.14)
# Collecting chest (from python-terrier)
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from python-terrier) (1.11.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from python-terrier) (1.4.0)
# Collecting nptyping==1.4.4 (from python-terrier)
#   Downloading nptyping-1.4.4-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: more_itertools in /opt/conda/lib/python3.10/site-packages (from python-terrier) (10.2.0)
# Collecting ir_datasets>=0.3.2 (from python-terrier)
#   Downloading ir_datasets-0.5.7-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.10/site-packages (from python-terrier) (0.14.1)
# Collecting ir_measures>=0.3.1 (from python-terrier)
#   Downloading ir_measures-0.3.3.tar.gz (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dill in /opt/conda/lib/python3.10/site-packages (from python-terrier) (0.3.8)
# Collecting pytrec_eval_terrier>=0.5.3 (from python-terrier)
#   Downloading pytrec_eval_terrier-0.5.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (777 bytes)
# Collecting typish>=1.7.0 (from nptyping==1.4.4->python-terrier)
#   Downloading typish-1.9.3-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (4.12.2)
# Collecting inscriptis>=2.2.0 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading inscriptis-2.5.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: lxml>=4.5.2 in /opt/conda/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (5.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (6.0.1)
# Collecting trec-car-tools>=2.5.4 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading trec_car_tools-2.6-py3-none-any.whl.metadata (640 bytes)
# Requirement already satisfied: lz4>=3.1.10 in /opt/conda/lib/python3.10/site-packages (from ir_datasets>=0.3.2->python-terrier) (4.3.3)
# Collecting warc3-wet>=0.2.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading warc3_wet-0.2.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting zlib-state>=0.1.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading zlib-state-0.1.6.tar.gz (9.5 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ijson>=3.1.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading ijson-3.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting unlzw3>=0.2.1 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading unlzw3-0.2.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting cwl-eval>=1.0.10 (from ir_measures>=0.3.1->python-terrier)
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->python-terrier) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->python-terrier) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->python-terrier) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->python-terrier) (2024.2.2)
# Collecting heapdict (from chest->python-terrier)
#   Downloading HeapDict-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/lib/python3.10/site-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->python-terrier) (2.1.3)
# Collecting multiset<3.0,>=2.0 (from matchpy->python-terrier)
#   Downloading multiset-2.1.1-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->python-terrier) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->python-terrier) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->python-terrier) (2023.4)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels->python-terrier) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.10/site-packages (from statsmodels->python-terrier) (21.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.4.1->ir_datasets>=0.3.2->python-terrier) (2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21.3->statsmodels->python-terrier) (3.1.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from patsy>=0.5.4->statsmodels->python-terrier) (1.16.0)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir_datasets>=0.3.2->python-terrier)
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Downloading ir_datasets-0.5.7-py3-none-any.whl (337 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.9/337.9 kB 15.0 MB/s eta 0:00:00
# Downloading pyjnius-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 47.3 MB/s eta 0:00:00
# Downloading pytrec_eval_terrier-0.5.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 14.9 MB/s eta 0:00:00
# Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 3.6 MB/s eta 0:00:00
# Downloading ijson-3.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 6.6 MB/s eta 0:00:00
# Downloading inscriptis-2.5.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 2.2 MB/s eta 0:00:00
# Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.2 MB/s eta 0:00:00
# Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Building wheels for collected packages: python-terrier, ir_measures, chest, wget, cwl-eval, warc3-wet-clueweb09, zlib-state, cbor
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.10.1-py3-none-any.whl size=117252 sha256=28369a3c8cda2d4118a8d83723f7ace32221c1edbe08af19973d8e9fcc53454d
#   Stored in directory: /root/.cache/pip/wheels/58/88/6d/fd8acd9b71f17907235017371cff103c736d40e55101783cc7
#   Building wheel for ir_measures (setup.py) ... done
#   Created wheel for ir_measures: filename=ir_measures-0.3.3-py3-none-any.whl size=61182 sha256=26854338d5ea457d8d01212fa51e1e07b84629d10565e247f9184036c166df4f
#   Stored in directory: /root/.cache/pip/wheels/9f/0e/22/718279f23fef1673a4c5e433881c25080a6afaa147e007183e
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7612 sha256=5d607bbab462ea3e737ad8ac7c0f11feef129f3db2445a1db2dd6b5daf1d5039
#   Stored in directory: /root/.cache/pip/wheels/88/cf/99/4773b31f855f9ecedc32a0ae400f7a4a3001b37c439b6d1a73
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=eb29aed58abb58cf4ca45697aa2cb152c9d886a01a2bb042e36f282458bef9ae
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38068 sha256=a2b87f6d056efcb576f6935d3cf2b52994421f473aea42d39d56918843d602de
#   Stored in directory: /root/.cache/pip/wheels/3d/c1/94/94a3e5379b1aa8fb7c7f1ad1956305d5edc98ef745b6067d87
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18919 sha256=a710bd945df909a080c9d502590dbc1ebcb36ce8bb14cd2b73c3bea726689adb
#   Stored in directory: /root/.cache/pip/wheels/1a/d7/91/7ffb991df87e62355d945745035470ba2616aa3d83a250b5f9
#   Building wheel for zlib-state (pyproject.toml) ... done
#   Created wheel for zlib-state: filename=zlib_state-0.1.6-cp310-cp310-linux_x86_64.whl size=11419 sha256=ef7e146b04b3b7396617cf58c3ab7a6ea37da636f98b2eaa9728c69d42a6a5c3
#   Stored in directory: /root/.cache/pip/wheels/32/72/7e/aff80f26e926b6e1fb08dfb52aba03c0e058f5e2258deb50a9
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp310-cp310-linux_x86_64.whl size=23238 sha256=81c4377a10cc0f8507e4587c38e3330df1fdd408f671788853551099b05de3a0
#   Stored in directory: /root/.cache/pip/wheels/85/df/c9/b39e40eccaf76dbd218556639a6dc81562226f4c6a64902c85
# Successfully built python-terrier ir_measures chest wget cwl-eval warc3-wet-clueweb09 zlib-state cbor
# Installing collected packages: wget, warc3-wet-clueweb09, warc3-wet, typish, pyjnius, multiset, ijson, heapdict, cbor, zlib-state, unlzw3, trec-car-tools, pytrec_eval_terrier, nptyping, matchpy, cwl-eval, chest, ir_measures, inscriptis, ir_datasets, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.12 heapdict-1.0.1 ijson-3.2.3 inscriptis-2.5.0 ir_datasets-0.5.7 ir_measures-0.3.3 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyjnius-1.6.1 python-terrier-0.10.1 pytrec_eval_terrier-0.5.6 trec-car-tools-2.6 typish-1.9.3 unlzw3-0.2.2 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
# !curl -s "https://get.sdkman.io" | bash && source "$HOME/.sdkman/bin/sdkman-init.sh" && sdk install java 11.0.22-amzn < /dev/null
# Out:
#                                 -+syyyyyyys:
#                             `/yho:`       -yd.
#                          `/yh/`             +m.
#                        .oho.                 hy                          .`
#                      .sh/`                   :N`                `-/o`  `+dyyo:.
#                    .yh:`                     `M-          `-/osysoym  :hs` `-+sys:      hhyssssssssy+
#                  .sh:`                       `N:          ms/-``  yy.yh-      -hy.    `.N-````````+N.
#                `od/`                         `N-       -/oM-      ddd+`     `sd:     hNNm        -N:
#               :do`                           .M.       dMMM-     `ms.      /d+`     `NMMs       `do
#             .yy-                             :N`    ```mMMM.      -      -hy.       /MMM:       yh
#           `+d+`           `:/oo/`       `-/osyh/ossssssdNMM`           .sh:         yMMN`      /m.
#          -dh-           :ymNMMMMy  `-/shmNm-`:N/-.``   `.sN            /N-         `NMMy      .m/
#        `oNs`          -hysosmMMMMydmNmds+-.:ohm           :             sd`        :MMM/      yy
#       .hN+           /d:    -MMMmhs/-.`   .MMMh   .ss+-                 `yy`       sMMN`     :N.
#      :mN/           `N/     `o/-`         :MMMo   +MMMN-         .`      `ds       mMMh      do
#     /NN/            `N+....--:/+oooosooo+:sMMM:   hMMMM:        `my       .m+     -MMM+     :N.
#    /NMo              -+ooooo+/:-....`...:+hNMN.  `NMMMd`        .MM/       -m:    oMMN.     hs
#   -NMd`                                    :mm   -MMMm- .s/     -MMm.       /m-   mMMd     -N.
#  `mMM/                                      .-   /MMh. -dMo     -MMMy        od. .MMMs..---yh
#  +MMM.                                           sNo`.sNMM+     :MMMM/        sh`+MMMNmNm+++-
#  mMMM-                                           /--ohmMMM+     :MMMMm.       `hyymmmdddo
#  MMMMh.                  ````                  `-+yy/`yMMM/     :MMMMMy       -sm:.``..-:-.`
#  dMMMMmo-.``````..-:/osyhddddho.           `+shdh+.   hMMM:     :MmMMMM/   ./yy/` `:sys+/+sh/
#  .dMMMMMMmdddddmmNMMMNNNNNMMMMMs           sNdo-      dMMM-  `-/yd/MMMMm-:sy+.   :hs-      /N`
#   `/ymNNNNNNNmmdys+/::----/dMMm:          +m-         mMMM+ohmo/.` sMMMMdo-    .om:       `sh
#      `.-----+/.`       `.-+hh/`         `od.          NMMNmds/     `mmy:`     +mMy      `:yy.
#            /moyso+//+ossso:.           .yy`          `dy+:`         ..       :MMMN+---/oys:
#          /+m:  `.-:::-`               /d+                                    +MMMMMMMNh:`
#         +MN/                        -yh.                                     `+hddhy+.
#        /MM+                       .sh:
#       :NMo                      -sh/
#      -NMs                    `/yy:
#     .NMy                  `:sh+.
#    `mMm`               ./yds-
#   `dMMMmyo:-.````.-:oymNy:`
#   +NMMMMMMMMMMMMMMMMms:`
#     -+shmNMMMNmdy+:`
#
#
#                                                                  Now attempting installation...
#
#
# Looking for a previous installation of SDKMAN...
# Looking for unzip...
# Looking for zip...
# Looking for curl...
# Looking for sed...
# Installing SDKMAN scripts...
# Create distribution directories...
# Getting available candidates...
# Prime platform file...
# Prime the config file...
# Installing script cli archive...
# * Downloading...
# ######################################################################## 100.0%
# * Checking archive integrity...
# * Extracting archive...
# * Copying archive contents...
# * Cleaning up...
#
# Installing script cli archive...
# * Downloading...
# ######################################################                    18.9%################## 100.0%
# * Checking archive integrity...
# * Extracting archive...
# * Copying archive contents...
# * Cleaning up...
#
# Set version to 5.18.2 ...
# Set native version to 0.4.6 ...
# Attempt update of interactive bash profile on regular UNIX...
# Added sdkman init snippet to /root/.bashrc
# Attempt update of zsh profile...
# Updated existing /root/.zshrc
#
#
#
# All done!
#
#
# You are subscribed to the STABLE channel.
#
# Please open a new terminal, or run the following in the existing one:
#
#     source "/root/.sdkman/bin/sdkman-init.sh"
#
# Then issue the following command:
#
#     sdk help
#
# Enjoy!!!
#
# Downloading: java 11.0.22-amzn
#
# In progress...
#
# ######################################################################## 100.0%
#
# Repackaging Java 11.0.22-amzn...
#
# Done repackaging...
#
# Installing: java 11.0.22-amzn
# Done installing!
#
#
# Setting java 11.0.22-amzn as default.

# %%
# !java --version

# %%
# %env JAVA_HOME=/root/.sdkman/candidates/java/current
import pyterrier as pt
if not pt.started():
    pt.init()
# Out:
# env: JAVA_HOME=/root/.sdkman/candidates/java/current
# terrier-assemblies 5.9 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.10.1 has loaded Terrier 5.9 (built by craigm on 2024-05-02 17:40) and terrier-helper 0.0.8
#
# No etc/terrier.properties, using terrier.default.properties for bootstrap configuration.
